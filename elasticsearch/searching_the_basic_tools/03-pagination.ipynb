# %% [markdown]
# five records

# %%
curl -XGET 'localhost:9200/_search?size=5&pretty'
# Out:
# {
#   "took" : 3,
#   "timed_out" : false,
#   "_shards" : {
#     "total" : 19,
#     "successful" : 19,
#     "failed" : 0
#   },
#   "hits" : {
#     "total" : 18,
#     "max_score" : 1.0,
#     "hits" : [
#       {
#         "_index" : ".kibana",
#         "_type" : "config",
#         "_id" : "5.2.2",
#         "_score" : 1.0,
#         "_source" : {
#           "buildNum" : 14723
#         }
#       },
#       {
#         "_index" : "us",
#         "_type" : "tweet",
#         "_id" : "14",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-24",
#           "name" : "John Smith",
#           "tweet" : "How many more cheesy tweets do I have to write?",
#           "user_id" : 1
#         }
#       },
#       {
#         "_index" : "gb",
#         "_type" : "tweet",
#         "_id" : "5",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-15",
#           "name" : "Mary Jones",
# ...

# %% [markdown]
# five records starting at five

# %%
curl -XGET 'localhost:9200/_search?size=5&from=5&pretty'
# Out:
# {
#   "took" : 2,
#   "timed_out" : false,
#   "_shards" : {
#     "total" : 19,
#     "successful" : 19,
#     "failed" : 0
#   },
#   "hits" : {
#     "total" : 18,
#     "max_score" : 1.0,
#     "hits" : [
#       {
#         "_index" : "us",
#         "_type" : "tweet",
#         "_id" : "10",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-20",
#           "name" : "John Smith",
#           "tweet" : "Elasticsearch surely is one of the hottest new NoSQL products",
#           "user_id" : 1
#         }
#       },
#       {
#         "_index" : "us",
#         "_type" : "tweet",
#         "_id" : "12",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-22",
#           "name" : "John Smith",
#           "tweet" : "Elasticsearch and I have left the honeymoon stage, and I still love her.",
#           "user_id" : 1
#         }
#       },
#       {
#         "_index" : "gb",
#         "_type" : "user",
# ...

# %% [markdown]
# five records starting at ten

# %%
curl -XGET 'localhost:9200/_search?size=5&from=10&pretty'
# Out:
# {
#   "took" : 1,
#   "timed_out" : false,
#   "_shards" : {
#     "total" : 19,
#     "successful" : 19,
#     "failed" : 0
#   },
#   "hits" : {
#     "total" : 18,
#     "max_score" : 1.0,
#     "hits" : [
#       {
#         "_index" : "us",
#         "_type" : "tweet",
#         "_id" : "6",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-16",
#           "name" : "John Smith",
#           "tweet" : "The Elasticsearch API is really easy to use",
#           "user_id" : 1
#         }
#       },
#       {
#         "_index" : "gb",
#         "_type" : "tweet",
#         "_id" : "7",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-17",
#           "name" : "Mary Jones",
#           "tweet" : "The Query DSL is really powerful and flexible",
#           "user_id" : 2
#         }
#       },
#       {
#         "_index" : "gb",
#         "_type" : "tweet",
#         "_id" : "13",
#         "_score" : 1.0,
# ...
