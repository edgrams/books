# %% [markdown]
# empty search, returns all data in the cluster

# %%
curl -XGET 'localhost:9200/_search?pretty'
# Out:
# {
#   "took" : 8,
#   "timed_out" : false,
#   "_shards" : {
#     "total" : 19,
#     "successful" : 19,
#     "failed" : 0
#   },
#   "hits" : {
#     "total" : 18,
#     "max_score" : 1.0,
#     "hits" : [
#       {
#         "_index" : ".kibana",
#         "_type" : "config",
#         "_id" : "5.2.2",
#         "_score" : 1.0,
#         "_source" : {
#           "buildNum" : 14723
#         }
#       },
#       {
#         "_index" : "us",
#         "_type" : "tweet",
#         "_id" : "14",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-24",
#           "name" : "John Smith",
#           "tweet" : "How many more cheesy tweets do I have to write?",
#           "user_id" : 1
#         }
#       },
#       {
#         "_index" : "gb",
#         "_type" : "tweet",
#         "_id" : "5",
#         "_score" : 1.0,
#         "_source" : {
#           "date" : "2014-09-15",
#           "name" : "Mary Jones",
# ...

# %% [markdown]
# empty search w/ timeout

# %%
curl -XGET 'localhost:9200/_search?timeout=10ms'
# Out:
# {"took":7,"timed_out":false,"_shards":{"total":19,"successful":19,"failed":0},"hits":{"total":18,"max_score":1.0,"hits":[{"_index":".kibana","_type":"config","_id":"5.2.2","_score":1.0,"_source":{"buildNum":14723}},{"_index":"us","_type":"tweet","_id":"14","_score":1.0,"_source":
# {
#    "date" : "2014-09-24",
#    "name" : "John Smith",
#    "tweet" : "How many more cheesy tweets do I have to write?",
#    "user_id" : 1
# }
# },{"_index":"gb","_type":"tweet","_id":"5","_score":1.0,"_source":
# {
#    "date" : "2014-09-15",
#    "name" : "Mary Jones",
#    "tweet" : "However did I manage before Elasticsearch?",
#    "user_id" : 2
# }
# },{"_index":"gb","_type":"tweet","_id":"9","_score":1.0,"_source":
# {
#    "date" : "2014-09-19",
#    "name" : "Mary Jones",
#    "tweet" : "Geo-location aggregations are really cool",
#    "user_id" : 2
# }
# },{"_index":"us","_type":"tweet","_id":"8","_score":1.0,"_source":
# {
#    "date" : "2014-09-18",
#    "name" : "John Smith",
# ...
